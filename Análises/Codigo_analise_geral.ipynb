# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#Paleta de cores do carnaval
my_palette = sns.color_palette(['#0455BF', '#0468BF', '#05C7F2', '#F2C84C', '#D95204'])

# %%
df=pd.read_csv('Downloads/df_carnaval.csv')

# %%
maiores_blocos = ['Baianas Ozadas', 'MONOBLOCO', 'Entao Brilha', 'Bloco Despedida de Carnaval']
tamanho_metade = int(df.shape[0]/2)
menores_blocos = list(df['bloco'].sort_values()[:tamanho_metade].index)
df['bloco_classificacao'] = df['bloco']
df.loc[~df['bloco_classificacao'].isin(maiores_blocos + menores_blocos), 'bloco_classificacao'] = 'Outros'

# %%
coluna_a = df.pop('bloco_classificacao') # remove a coluna do DataFrame e a armazena em uma variável separada
df.insert(4, 'bloco_classificacao', coluna_a) # insere a coluna na posição 2

# %%
df.to_csv('df_new.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0  numero_controle        idade  t_qtpernoite  dias_carnaval  \
# count  1645.000000      1645.000000  1645.000000    210.000000    1645.000000
# mean    822.000000       823.000000    30.454103      6.328571       3.843769
# std     475.014912       475.014912    11.690186     12.878588       1.664509
# min       0.000000         1.000000    16.000000      1.000000       1.000000
# 25%     411.000000       412.000000    22.000000      4.000000       2.000000
# 50%     822.000000       823.000000    27.000000      4.000000       4.000000
# 75%    1233.000000      1234.000000    37.000000      6.000000       5.000000
# max    1644.000000      1645.000000    74.000000    180.000000       6.000000
#
#         gasto_total  t_hospedagem.1  alimentacao  t_atrativos_passeios  \
# count   1623.000000       40.000000  1559.000000            181.000000
# mean     359.009673      737.125000   205.440026            266.585635
# std      891.222926     1183.686055   253.240412           1519.026175
# min        3.000000       40.000000     2.000000              4.000000
# 25%      115.000000      230.000000    70.000000             50.000000
# 50%      230.000000      340.000000   150.000000            100.000000
# 75%      403.500000      600.000000   250.000000            200.000000
# max    31201.000000     6820.000000  5000.000000          20460.000000
#
#        transporte_interno      compras    ingressos       outros  \
# count         1191.000000   513.000000   102.000000   244.000000
# mean            73.486146    94.497076   138.715686   130.500000
# std             89.688319   161.262162   158.155167   266.857609
# min              4.000000     1.000000    10.000000     3.000000
# 25%             25.000000    20.000000    40.000000    30.000000
# 50%             50.000000    50.000000   100.000000    50.000000
# 75%            100.000000   100.000000   153.000000   100.000000
# max           1500.000000  2000.000000  1000.000000  2500.000000
#
#               total  qtd_pessoas_gasto   aval_geral  aval_banheiros  \
# count   1622.000000        1644.000000  1615.000000     1641.000000
# mean     357.203884           1.524331     5.191331        7.170628
# std      894.586091           1.055959     2.607524        2.221050
# min        3.000000           1.000000     1.000000        1.000000
# 25%      106.500000           1.000000     3.000000        6.000000
# 50%      220.000000           1.000000     5.000000        8.000000
# 75%      400.000000           2.000000     7.000000        9.000000
# max    31201.000000          10.000000    10.000000       10.000000
#
#        aval_seguranca  aval_precos
# count     1638.000000  1644.000000
# mean         6.669109     8.339416
# std          2.217366     1.379929
# min          1.000000     1.000000
# 25%          5.000000     8.000000
# 50%          7.000000     8.000000
# 75%          8.000000     9.000000
# max         10.000000    10.000000

# %%
# Criando outra coluna para classificar a renda:
df['faixa_renda'].value_counts()
# Out:
# de 2 a 3 salarios (R$ 1875,00 – R$ 2862,00)     287
# de 1 a 2 salarios (R$ 954,00 – R$ 1908,00)      257
# de 3 a 4 salarios (R$ 2812,00 – R$ 3816,00)     246
# de 4 a 5 salarios (R$ 3749,00 – R$ 4770,00)     193
# de 5 a 6 salarios (R$ 4686,00 – R$ 5724,00)     137
# Acima de 10 salarios (acima de R$ 9540,00)      135
# de 6 a 7 salarios (R$ 5623,00 – R$ 6678,00)     100
# Ate um salario minimo (R$ 954,00 )               66
# de 7 a 8 salarios (R$ 6560,00 – R$ 7632,00)      64
# de 9 a 10 salarios (R$ 8434,00 – R$ 9540,00)     56
# de 8 a 9 salarios (R$ 7497,00 – R$ 8586,00)      40
# Nao respondeu                                    34
# Nao sabe                                         30
# Name: faixa_renda, dtype: int64

# %%
df=df.drop(df[df['faixa_renda']=='Nao respondeu'].index)
df=df.drop(df[df['faixa_renda']=='Nao sabe'].index)
df=df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       1581 non-null   int64
#  1   Unnamed: 0                  1581 non-null   int64
#  2   morador                     1581 non-null   object
#  3   numero_controle             1581 non-null   int64
#  4   bloco                       1581 non-null   object
#  5   bloco_classificacao         1581 non-null   object
#  6   dt_visita                   1581 non-null   object
#  7   dt_termino                  1581 non-null   object
#  8   tempo_total_entrev          1581 non-null   object
#  9   idade                       1581 non-null   int64
#  10  pais                        1581 non-null   object
#  11  estado                      1577 non-null   object
#  12  cidade                      1577 non-null   object
#  13  bairro_bh                   1090 non-null   object
#  14  regiao_bh                   1090 non-null   object
#  15  t_pernoite                  217 non-null    object
#  16  t_qtpernoite                200 non-null    float64
#  17  t_hospedagem                200 non-null    object
#  18  t_transp                    201 non-null    object
#  19  t_motivo                    218 non-null    object
#  20  t_outromoivo                45 non-null     object
#  21  dias_carnaval               1581 non-null   int64
#  22  gasto_total                 1562 non-null   float64
#  23  t_hospedagem.1              39 non-null     float64
#  24  alimentacao                 1499 non-null   float64
#  25  t_atrativos_passeios        172 non-null    float64
#  26  transporte_interno          1147 non-null   float64
#  27  compras                     489 non-null    float64
#  28  ingressos                   97 non-null     float64
#  29  outros                      236 non-null    float64
#  30  total                       1561 non-null   float64
#  31  qtd_pessoas_gasto           1580 non-null   float64
#  32  fonte_carnaval              1581 non-null   object
#  33  participou_anos_anteriores  1581 non-null   object
#  34  evolucao                    1165 non-null   object
#  35  motivo                      62 non-null     object
#  36  expectativas                1581 non-null   object
#  37  aval_geral                  1553 non-null   float64
#  38  aval_banheiros              1577 non-null   float64
#  39  aval_seguranca              1576 non-null   float64
#  40  aval_precos                 1580 non-null   float64
#  41  proxima_edicao              1581 non-null   bool
#  42  motivo_nao                  99 non-null     object
#  43  blocos_de_rua               1581 non-null   bool
#  44  escola_samba_caricato       1581 non-null   bool
#  45  eventos_privados            1581 non-null   bool
#  46  palcos                      1581 non-null   bool
#  47  t_visita_amigos             218 non-null    object
#  48  t_city_tour                 218 non-null    object
#  49  t_visita_cultural           218 non-null    object
#  50  t_compras                   218 non-null    object
#  51  t_gastronomia               218 non-null    object
#  52  principal_patrocinador      1581 non-null   object
#  53  outro_patrocinador          623 non-null    object
#  54  genero                      1581 non-null   object
#  55  escolaridade                1581 non-null   object
#  56  estado_civil                1581 non-null   object
#  57  faixa_renda                 1581 non-null   object
# dtypes: bool(5), float64(15), int64(5), object(33)
# memory usage: 662.5+ KB

# %%
# Dicionário com os intervalos e seus respectivos valores inteiros
intervalos = {
    'Ate um salario minimo (R$ 954,00 )': 1,
    'de 1 a 2 salarios (R$ 954,00 – R$ 1908,00)': 2,
    'de 2 a 3 salarios (R$ 1875,00 – R$ 2862,00)': 3,
    'de 3 a 4 salarios (R$ 2812,00 – R$ 3816,00)': 4,
    'de 4 a 5 salarios (R$ 3749,00 – R$ 4770,00)': 5,
    'de 5 a 6 salarios (R$ 4686,00 – R$ 5724,00)': 6,
    'de 6 a 7 salarios (R$ 5623,00 – R$ 6678,00)': 7,
    'de 7 a 8 salarios (R$ 6560,00 – R$ 7632,00)': 8,
    'de 8 a 9 salarios (R$ 7497,00 – R$ 8586,00)': 9,
    'de 9 a 10 salarios (R$ 8434,00 – R$ 9540,00)': 10,
    'Acima de 10 salarios (acima de R$ 9540,00)': 11
}
df['faixa_renda']=df['faixa_renda'].astype(str)
df['int_renda'] = df['faixa_renda'].apply(lambda x: intervalos[x])

# %%
# Comparando gastos financeiros com características pessoais.
financeiro=['int_renda','gasto_total', 't_hospedagem.1', 'alimentacao', 't_atrativos_passeios', 'transporte_interno', 'compras', 'ingressos', 'outros', 'total']
pessoal=['idade', 'aval_geral', 'aval_banheiros', 'aval_seguranca', 'aval_precos']

# %%
df.corr().loc[financeiro, pessoal]
# Out:
#                          idade  aval_geral  aval_banheiros  aval_seguranca  \
# int_renda             0.111156   -0.021877        0.032484        0.142113
# gasto_total           0.049189   -0.070835        0.051471        0.115428
# t_hospedagem.1        0.178608   -0.262337        0.125256       -0.007343
# alimentacao           0.058304   -0.032665        0.043213        0.110827
# t_atrativos_passeios  0.104827   -0.160883       -0.010717        0.088351
# transporte_interno    0.073653   -0.037957        0.022455        0.076711
# compras               0.118469   -0.078682        0.108735        0.116996
# ingressos            -0.096888   -0.176779        0.125604        0.009734
# outros                0.117480   -0.098447       -0.028394        0.065939
# total                 0.058449   -0.066768        0.051884        0.118714
#
#                       aval_precos
# int_renda               -0.006962
# gasto_total              0.027398
# t_hospedagem.1          -0.401657
# alimentacao              0.076960
# t_atrativos_passeios    -0.127238
# transporte_interno       0.046049
# compras                  0.103789
# ingressos               -0.051578
# outros                  -0.030437
# total                    0.032035

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(df.corr().loc[financeiro, pessoal], annot=True, cmap='coolwarm', ax=ax)
# Out:
# <AxesSubplot:>

# %%
#Quanto maior os gastos, menor a avaliação geral

# %%
renda=df.pivot_table(index=['int_renda', 'genero'], values='aval_geral', aggfunc='mean')

# %%
g = sns.catplot(x='int_renda', y='aval_geral', kind='bar', data=df, col='genero', ci=None, palette=my_palette, height=6, aspect=1.5)
g.set_axis_labels('Faixa de renda', 'Avaliação geral')

plt.show()

# %%
g = sns.catplot(x='dias_carnaval', y='aval_geral', kind='bar', data=df, ci=None, palette=my_palette, height=6, aspect=1.5)
g.set_axis_labels('Dias no Carnaval', 'Avaliação geral')

# %%
blocos=df.pivot_table(index='bloco', values='aval_geral', aggfunc='mean')

# %%
blocos
# Out:
#                              aval_geral
# bloco
# Alo Abacaxi                    5.290323
# Baianas Ozadas                 5.108317
# Batiza                         5.628571
# Beiço do Vando                 6.558824
# Bloco Angola Janga             4.528302
# Bloco Despedida de Carnaval    5.860870
# Bloco Havayanas Usadas         7.035714
# Bloco da Calixto               5.142857
# Bloco e o Amo                  5.333333
# Entao Brilha                   5.758621
# Funk You                       4.972222
# Juventude Bronzeada            5.244681
# MONOBLOCO                      4.329502
# Quando come se lambuza         4.439024
# Tchanzinho Zona Norte          6.229167

# %%
blocos.sort_values(by= 'Unnamed: 0', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 blocos.sort_values(by= 'Unnamed: 0', ascending=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
#    6315     # need to rewrap column in Series to apply key function
#    6316     if key is not None:
#    6317         # error: Incompatible types in assignment (expression has type
#    6318         # "Series", variable has type "ndarray")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Unnamed: 0'
